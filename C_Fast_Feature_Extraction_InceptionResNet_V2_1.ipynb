# %% [raw]
# Entreno de un ConvNet Inception ResNet V2 preentrenado con Imagenet y
# entrenando conjunto de datos pequeño
# Conjunto de datos de 4 clases
# Utilizaremos un conjunto de datos reducido:
# - Conjunto de entrenamiento: 1.000 muestras x clase
# - Conjunto de validación: 300 muestras x clase
# - Conjunto de test: 300 muestras x clase
# El conjunto de datos: balanced_dataset
# contiene tres carpetas, train, validation y test, cada una con 4 clases

# %%
##########CREATE MODEL INCEPTIONResNet V2#######################################
from keras.layers import Input, merge, Dropout, Dense, Lambda, Flatten, Activation
from keras.layers.convolutional import MaxPooling2D, Convolution2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model

from keras import backend as K

import warnings
warnings.filterwarnings('ignore')

"""
Implementation of Inception-Residual Network v1 [Inception Network v4 Paper](http://arxiv.org/pdf/1602.07261v1.pdf) in Keras.

Some additional details:
[1] Each of the A, B and C blocks have a 'scale_residual' parameter.
    The scale residual parameter is according to the paper. It is however turned OFF by default.

    Simply setting 'scale=True' in the create_inception_resnet_v2() method will add scaling.

[2] There were minor inconsistencies with filter size in both B and C blocks.

    In the B blocks: 'ir_conv' nb of filters  is given as 1154, however input size is 1152.
    This causes inconsistencies in the merge-add mode, therefore the 'ir_conv' filter size
    is reduced to 1152 to match input size.

    In the C blocks: 'ir_conv' nb of filter is given as 2048, however input size is 2144.
    This causes inconsistencies in the merge-add mode, therefore the 'ir_conv' filter size
    is increased to 2144 to match input size.

    Currently trying to find a proper solution with original nb of filters.

[3] In the stem function, the last Convolutional2D layer has 384 filters instead of the original 256.
    This is to correctly match the nb of filters in 'ir_conv' of the next A blocks.
"""

def inception_resnet_stem(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input Shape is 299 x 299 x 3 (th) or 3 x 299 x 299 (th)
    c = Convolution2D(32, 3, 3, activation='relu', subsample=(2, 2))(input)
    c = Convolution2D(32, 3, 3, activation='relu', )(c)
    c = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(c)

    c1 = MaxPooling2D((3, 3), strides=(2, 2))(c)
    c2 = Convolution2D(96, 3, 3, activation='relu', subsample=(2, 2))(c)

    m = merge([c1, c2], mode='concat', concat_axis=channel_axis)

    c1 = Convolution2D(64, 1, 1, activation='relu', border_mode='same')(m)
    c1 = Convolution2D(96, 3, 3, activation='relu', )(c1)

    c2 = Convolution2D(64, 1, 1, activation='relu', border_mode='same')(m)
    c2 = Convolution2D(64, 7, 1, activation='relu', border_mode='same')(c2)
    c2 = Convolution2D(64, 1, 7, activation='relu', border_mode='same')(c2)
    c2 = Convolution2D(96, 3, 3, activation='relu', border_mode='valid')(c2)

    m2 = merge([c1, c2], mode='concat', concat_axis=channel_axis)

    p1 = MaxPooling2D((3, 3), strides=(2, 2), )(m2)
    p2 = Convolution2D(192, 3, 3, activation='relu', subsample=(2, 2))(m2)

    m3 = merge([p1, p2], mode='concat', concat_axis=channel_axis)
    m3 = BatchNormalization(axis=channel_axis)(m3)
    m3 = Activation('relu')(m3)
    return m3

def inception_resnet_v2_A(input, scale_residual=True):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input is relu activation
    init = input

    ir1 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(ir2)

    ir3 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)
    ir3 = Convolution2D(48, 3, 3, activation='relu', border_mode='same')(ir3)
    ir3 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(ir3)

    ir_merge = merge([ir1, ir2, ir3], concat_axis=channel_axis, mode='concat')

    ir_conv = Convolution2D(384, 1, 1, activation='linear', border_mode='same')(ir_merge)
    if scale_residual: ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=channel_axis)(out)
    out = Activation("relu")(out)
    return out

def inception_resnet_v2_B(input, scale_residual=True):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input is relu activation
    init = input

    ir1 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(128, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(160, 1, 7, activation='relu', border_mode='same')(ir2)
    ir2 = Convolution2D(192, 7, 1, activation='relu', border_mode='same')(ir2)

    ir_merge = merge([ir1, ir2], mode='concat', concat_axis=channel_axis)

    ir_conv = Convolution2D(1152, 1, 1, activation='linear', border_mode='same')(ir_merge)
    if scale_residual: ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=channel_axis)(out)
    out = Activation("relu")(out)
    return out

def inception_resnet_v2_C(input, scale_residual=True):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input is relu activation
    init = input

    ir1 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(224, 1, 3, activation='relu', border_mode='same')(ir2)
    ir2 = Convolution2D(256, 3, 1, activation='relu', border_mode='same')(ir2)

    ir_merge = merge([ir1, ir2], mode='concat', concat_axis=channel_axis)

    ir_conv = Convolution2D(2144, 1, 1, activation='linear', border_mode='same')(ir_merge)
    if scale_residual: ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=channel_axis)(out)
    out = Activation("relu")(out)
    return out


def reduction_A(input, k=192, l=224, m=256, n=384):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = MaxPooling2D((3,3), strides=(2,2))(input)

    r2 = Convolution2D(n, 3, 3, activation='relu', subsample=(2,2))(input)

    r3 = Convolution2D(k, 1, 1, activation='relu', border_mode='same')(input)
    r3 = Convolution2D(l, 3, 3, activation='relu', border_mode='same')(r3)
    r3 = Convolution2D(m, 3, 3, activation='relu', subsample=(2,2))(r3)

    m = merge([r1, r2, r3], mode='concat', concat_axis=channel_axis)
    m = BatchNormalization(axis=1)(m)
    m = Activation('relu')(m)
    return m


def reduction_resnet_v2_B(input):
    if K.image_dim_ordering() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = MaxPooling2D((3,3), strides=(2,2), border_mode='valid')(input)

    r2 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r2 = Convolution2D(384, 3, 3, activation='relu', subsample=(2,2))(r2)

    r3 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r3 = Convolution2D(288, 3, 3, activation='relu', subsample=(2, 2))(r3)

    r4 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r4 = Convolution2D(288, 3, 3, activation='relu', border_mode='same')(r4)
    r4 = Convolution2D(320, 3, 3, activation='relu', subsample=(2, 2))(r4)

    m = merge([r1, r2, r3, r4], concat_axis=channel_axis, mode='concat')
    m = BatchNormalization(axis=channel_axis)(m)
    m = Activation('relu')(m)
    return m

def create_inception_resnet_v2(nb_classes=1001, scale=True):
    '''
    Creates a inception resnet v2 network

    :param nb_classes: number of classes.txt
    :param scale: flag to add scaling of activations
    :return: Keras Model with 1 input (299x299x3) input shape and 2 outputs (final_output, auxiliary_output)
    '''

    if K.image_dim_ordering() == 'th':
        init = Input((3, 299, 299))
    else:
        init = Input((299, 299, 3))

    # Input Shape is 299 x 299 x 3 (tf) or 3 x 299 x 299 (th)
    x = inception_resnet_stem(init)

    # 10 x Inception Resnet A
    for i in range(10):
        x = inception_resnet_v2_A(x, scale_residual=scale)

    # Reduction A
    x = reduction_A(x, k=256, l=256, m=384, n=384)

    # 20 x Inception Resnet B
    for i in range(20):
        x = inception_resnet_v2_B(x, scale_residual=scale)

    # Auxiliary tower
    aux_out = AveragePooling2D((5, 5), strides=(3, 3))(x)
    aux_out = Convolution2D(128, 1, 1, border_mode='same', activation='relu')(aux_out)
    aux_out = Convolution2D(768, 5, 5, activation='relu')(aux_out)
    aux_out = Flatten()(aux_out)
    aux_out = Dense(nb_classes, activation='softmax')(aux_out)

    # Reduction Resnet B
    x = reduction_resnet_v2_B(x)

    # 10 x Inception Resnet C
    for i in range(10):
        x = inception_resnet_v2_C(x, scale_residual=scale)

    # Average Pooling
    x = AveragePooling2D((8,8))(x)

    # Dropout
    x = Dropout(0.8)(x)
    x = Flatten()(x)

    # Output
    out = Dense(output_dim=nb_classes, activation='softmax')(x)

    model = Model(init, output=[out, aux_out], name='Inception-Resnet-v2')
    return model

if __name__ == "__main__":
    #from keras.utils.visualize_util import plot

    inception_resnet_v2 = create_inception_resnet_v2()
    inception_resnet_v2.summary()

    #plot(inception_resnet_v2, to_file="Inception ResNet-v2.png", show_shapes=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 149, 149, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 147, 147, 64) 18496       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 73, 73, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 73, 73, 96)   55392       conv2d_3[0][0]
# __________________________________________________________________________________________________
# merge_1 (Merge)                 (None, 73, 73, 160)  0           max_pooling2d_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 73, 73, 64)   10304       merge_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 73, 73, 64)   28736       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 73, 73, 64)   10304       merge_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 73, 73, 64)   28736       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 71, 71, 96)   55392       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 71, 71, 96)   55392       conv2d_9[0][0]
# __________________________________________________________________________________________________
# merge_2 (Merge)                 (None, 71, 71, 192)  0           conv2d_6[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 35, 35, 192)  0           merge_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 192)  331968      merge_2[0][0]
# __________________________________________________________________________________________________
# merge_3 (Merge)                 (None, 35, 35, 384)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 35, 35, 384)  1536        merge_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 35, 35, 384)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 32)   12320       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 32)   12320       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 32)   12320       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_16[0][0]
# __________________________________________________________________________________________________
# merge_4 (Merge)                 (None, 35, 35, 128)  0           conv2d_12[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 384)  49536       merge_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 35, 35, 384)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# merge_5 (Merge)                 (None, 35, 35, 384)  0           activation_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 35, 35, 384)  1536        merge_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 35, 35, 384)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 32)   12320       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 32)   12320       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 32)   12320       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_23[0][0]
# __________________________________________________________________________________________________
# merge_6 (Merge)                 (None, 35, 35, 128)  0           conv2d_19[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 384)  49536       merge_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 35, 35, 384)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# merge_7 (Merge)                 (None, 35, 35, 384)  0           activation_2[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 35, 35, 384)  1536        merge_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 35, 35, 384)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 32)   12320       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 32)   12320       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 32)   12320       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_30[0][0]
# __________________________________________________________________________________________________
# merge_8 (Merge)                 (None, 35, 35, 128)  0           conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 35, 35, 384)  49536       merge_8[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 35, 35, 384)  0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# merge_9 (Merge)                 (None, 35, 35, 384)  0           activation_3[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 35, 35, 384)  1536        merge_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 35, 35, 384)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 35, 35, 32)   12320       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 35, 35, 32)   12320       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 35, 35, 32)   12320       activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_37[0][0]
# __________________________________________________________________________________________________
# merge_10 (Merge)                (None, 35, 35, 128)  0           conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 35, 35, 384)  49536       merge_10[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 35, 35, 384)  0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# merge_11 (Merge)                (None, 35, 35, 384)  0           activation_4[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 384)  1536        merge_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 384)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 35, 35, 32)   12320       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 35, 35, 32)   12320       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 35, 35, 32)   12320       activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_44[0][0]
# __________________________________________________________________________________________________
# merge_12 (Merge)                (None, 35, 35, 128)  0           conv2d_40[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 35, 35, 384)  49536       merge_12[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 35, 35, 384)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# merge_13 (Merge)                (None, 35, 35, 384)  0           activation_5[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 384)  1536        merge_13[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 384)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 35, 35, 32)   12320       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 35, 35, 32)   12320       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 35, 35, 32)   12320       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_51[0][0]
# __________________________________________________________________________________________________
# merge_14 (Merge)                (None, 35, 35, 128)  0           conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 35, 35, 384)  49536       merge_14[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 35, 35, 384)  0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# merge_15 (Merge)                (None, 35, 35, 384)  0           activation_6[0][0]
#                                                                  lambda_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 384)  1536        merge_15[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 384)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 35, 35, 32)   12320       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 35, 35, 32)   12320       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 35, 35, 32)   12320       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_58[0][0]
# __________________________________________________________________________________________________
# merge_16 (Merge)                (None, 35, 35, 128)  0           conv2d_54[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 35, 35, 384)  49536       merge_16[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 35, 35, 384)  0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# merge_17 (Merge)                (None, 35, 35, 384)  0           activation_7[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 384)  1536        merge_17[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 384)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 35, 35, 32)   12320       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 35, 35, 32)   12320       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 35, 35, 32)   12320       activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_65[0][0]
# __________________________________________________________________________________________________
# merge_18 (Merge)                (None, 35, 35, 128)  0           conv2d_61[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 35, 35, 384)  49536       merge_18[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 35, 35, 384)  0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# merge_19 (Merge)                (None, 35, 35, 384)  0           activation_8[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 384)  1536        merge_19[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 384)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 35, 35, 32)   12320       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 35, 35, 32)   12320       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 35, 35, 32)   12320       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_72[0][0]
# __________________________________________________________________________________________________
# merge_20 (Merge)                (None, 35, 35, 128)  0           conv2d_68[0][0]
#                                                                  conv2d_70[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 35, 35, 384)  49536       merge_20[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 35, 35, 384)  0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# merge_21 (Merge)                (None, 35, 35, 384)  0           activation_9[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 384)  1536        merge_21[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 384)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 35, 35, 32)   12320       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 35, 35, 32)   12320       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 35, 35, 48)   13872       conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 35, 35, 32)   12320       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 35, 35, 32)   9248        conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 35, 35, 64)   27712       conv2d_79[0][0]
# __________________________________________________________________________________________________
# merge_22 (Merge)                (None, 35, 35, 128)  0           conv2d_75[0][0]
#                                                                  conv2d_77[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 35, 35, 384)  49536       merge_22[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 35, 35, 384)  0           conv2d_81[0][0]
# __________________________________________________________________________________________________
# merge_23 (Merge)                (None, 35, 35, 384)  0           activation_10[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 384)  1536        merge_23[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 384)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 35, 35, 256)  98560       activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 35, 35, 256)  590080      conv2d_83[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 17, 17, 384)  0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 17, 17, 384)  1327488     activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 17, 17, 384)  885120      conv2d_84[0][0]
# __________________________________________________________________________________________________
# merge_24 (Merge)                (None, 17, 17, 1152) 0           max_pooling2d_3[0][0]
#                                                                  conv2d_82[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 17, 17, 1152) 68          merge_24[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 17, 17, 128)  147584      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 17, 17, 160)  143520      conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 17, 17, 192)  221376      activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 17, 17, 192)  215232      conv2d_88[0][0]
# __________________________________________________________________________________________________
# merge_25 (Merge)                (None, 17, 17, 384)  0           conv2d_86[0][0]
#                                                                  conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 17, 17, 1152) 443520      merge_25[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 17, 17, 1152) 0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# merge_26 (Merge)                (None, 17, 17, 1152) 0           activation_12[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 17, 17, 1152) 4608        merge_26[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 17, 17, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 17, 17, 160)  143520      conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 17, 17, 192)  221376      activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 17, 17, 192)  215232      conv2d_93[0][0]
# __________________________________________________________________________________________________
# merge_27 (Merge)                (None, 17, 17, 384)  0           conv2d_91[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 17, 17, 1152) 443520      merge_27[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 17, 17, 1152) 0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# merge_28 (Merge)                (None, 17, 17, 1152) 0           activation_13[0][0]
#                                                                  lambda_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 17, 17, 1152) 4608        merge_28[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 17, 17, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 17, 17, 160)  143520      conv2d_97[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 17, 17, 192)  221376      activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 17, 17, 192)  215232      conv2d_98[0][0]
# __________________________________________________________________________________________________
# merge_29 (Merge)                (None, 17, 17, 384)  0           conv2d_96[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 17, 17, 1152) 443520      merge_29[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 17, 17, 1152) 0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# merge_30 (Merge)                (None, 17, 17, 1152) 0           activation_14[0][0]
#                                                                  lambda_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 17, 17, 1152) 4608        merge_30[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 17, 17, 128)  147584      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 17, 17, 160)  143520      conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 17, 17, 192)  221376      activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 17, 17, 192)  215232      conv2d_103[0][0]
# __________________________________________________________________________________________________
# merge_31 (Merge)                (None, 17, 17, 384)  0           conv2d_101[0][0]
#                                                                  conv2d_104[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 17, 17, 1152) 443520      merge_31[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 17, 17, 1152) 0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# merge_32 (Merge)                (None, 17, 17, 1152) 0           activation_15[0][0]
#                                                                  lambda_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 17, 17, 1152) 4608        merge_32[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 17, 17, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 17, 17, 160)  143520      conv2d_107[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 17, 17, 192)  221376      activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 17, 17, 192)  215232      conv2d_108[0][0]
# __________________________________________________________________________________________________
# merge_33 (Merge)                (None, 17, 17, 384)  0           conv2d_106[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 17, 17, 1152) 443520      merge_33[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 17, 17, 1152) 0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# merge_34 (Merge)                (None, 17, 17, 1152) 0           activation_16[0][0]
#                                                                  lambda_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 17, 17, 1152) 4608        merge_34[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 17, 17, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 17, 17, 160)  143520      conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 17, 17, 192)  221376      activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 17, 17, 192)  215232      conv2d_113[0][0]
# __________________________________________________________________________________________________
# merge_35 (Merge)                (None, 17, 17, 384)  0           conv2d_111[0][0]
#                                                                  conv2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 17, 17, 1152) 443520      merge_35[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 17, 17, 1152) 0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# merge_36 (Merge)                (None, 17, 17, 1152) 0           activation_17[0][0]
#                                                                  lambda_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 17, 17, 1152) 4608        merge_36[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 17, 17, 1152) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 17, 17, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 17, 17, 160)  143520      conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 17, 17, 192)  221376      activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 17, 17, 192)  215232      conv2d_118[0][0]
# __________________________________________________________________________________________________
# merge_37 (Merge)                (None, 17, 17, 384)  0           conv2d_116[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 17, 17, 1152) 443520      merge_37[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 17, 17, 1152) 0           conv2d_120[0][0]
# __________________________________________________________________________________________________
# merge_38 (Merge)                (None, 17, 17, 1152) 0           activation_18[0][0]
#                                                                  lambda_17[0][0]
# ...
# lambda_34 (Lambda)              (None, 8, 8, 2144)   0           conv2d_214[0][0]
# __________________________________________________________________________________________________
# merge_73 (Merge)                (None, 8, 8, 2144)   0           activation_36[0][0]
#                                                                  lambda_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 2144)   8576        merge_73[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 8, 8, 192)    411840      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_216[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 8, 8, 192)    411840      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 8, 8, 256)    172288      conv2d_217[0][0]
# __________________________________________________________________________________________________
# merge_74 (Merge)                (None, 8, 8, 448)    0           conv2d_215[0][0]
#                                                                  conv2d_218[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 8, 8, 2144)   962656      merge_74[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 8, 8, 2144)   0           conv2d_219[0][0]
# __________________________________________________________________________________________________
# merge_75 (Merge)                (None, 8, 8, 2144)   0           activation_37[0][0]
#                                                                  lambda_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 2144)   8576        merge_75[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 8, 8, 192)    411840      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_221[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 8, 8, 192)    411840      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 8, 8, 256)    172288      conv2d_222[0][0]
# __________________________________________________________________________________________________
# merge_76 (Merge)                (None, 8, 8, 448)    0           conv2d_220[0][0]
#                                                                  conv2d_223[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 8, 8, 2144)   962656      merge_76[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 8, 8, 2144)   0           conv2d_224[0][0]
# __________________________________________________________________________________________________
# merge_77 (Merge)                (None, 8, 8, 2144)   0           activation_38[0][0]
#                                                                  lambda_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 2144)   8576        merge_77[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 8, 8, 192)    411840      activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_226[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 8, 8, 192)    411840      activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 8, 8, 256)    172288      conv2d_227[0][0]
# __________________________________________________________________________________________________
# merge_78 (Merge)                (None, 8, 8, 448)    0           conv2d_225[0][0]
#                                                                  conv2d_228[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 8, 8, 2144)   962656      merge_78[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 8, 8, 2144)   0           conv2d_229[0][0]
# __________________________________________________________________________________________________
# merge_79 (Merge)                (None, 8, 8, 2144)   0           activation_39[0][0]
#                                                                  lambda_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 2144)   8576        merge_79[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 8, 8, 192)    411840      activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_231[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 8, 8, 192)    411840      activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 8, 8, 256)    172288      conv2d_232[0][0]
# __________________________________________________________________________________________________
# merge_80 (Merge)                (None, 8, 8, 448)    0           conv2d_230[0][0]
#                                                                  conv2d_233[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 8, 8, 2144)   962656      merge_80[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 8, 8, 2144)   0           conv2d_234[0][0]
# __________________________________________________________________________________________________
# merge_81 (Merge)                (None, 8, 8, 2144)   0           activation_40[0][0]
#                                                                  lambda_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 2144)   8576        merge_81[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 8, 8, 192)    411840      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_236[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 8, 8, 192)    411840      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 8, 8, 256)    172288      conv2d_237[0][0]
# __________________________________________________________________________________________________
# merge_82 (Merge)                (None, 8, 8, 448)    0           conv2d_235[0][0]
#                                                                  conv2d_238[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 8, 8, 2144)   962656      merge_82[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 8, 8, 2144)   0           conv2d_239[0][0]
# __________________________________________________________________________________________________
# merge_83 (Merge)                (None, 8, 8, 2144)   0           activation_41[0][0]
#                                                                  lambda_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 2144)   8576        merge_83[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 8, 8, 192)    411840      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 8, 8, 224)    129248      conv2d_241[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 8, 8, 192)    411840      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 8, 8, 256)    172288      conv2d_242[0][0]
# __________________________________________________________________________________________________
# merge_84 (Merge)                (None, 8, 8, 448)    0           conv2d_240[0][0]
#                                                                  conv2d_243[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 8, 8, 2144)   962656      merge_84[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 8, 8, 2144)   0           conv2d_244[0][0]
# __________________________________________________________________________________________________
# merge_85 (Merge)                (None, 8, 8, 2144)   0           activation_42[0][0]
#                                                                  lambda_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 2144)   8576        merge_85[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 2144)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 5, 5, 1152)   0           activation_32[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 2144)   0           activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 5, 5, 128)    147584      average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 1, 2144)   0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 1, 1, 768)    2458368     conv2d_186[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2144)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 768)          0           conv2d_187[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1001)         2147145     flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1001)         769769      flatten_1[0][0]
# ==================================================================================================
# Total params: 58,837,142
# Trainable params: 58,735,412
# Non-trainable params: 101,730
# __________________________________________________________________________________________________

# %%
import os, shutil
from os import walk, getcwd
# Retorna todos los archivos de un directorio dado
def ls(ruta):  
    return next(walk(ruta))[2]

height_image = 299
width_image = 299
channels_image = 3
nb_clases = 4
batch_size = 2
class_mode = 'categorical'
nb_train = 4000        # 1000 x 4 clases
nb_validation = 1200   #  300 x 4 clases
nb_test = 1200

base_dir = 'balanced_dataset'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

# %%
#Extracción de características del modelo Preentrenado y nuestro dataset
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical

#Tamaño de salida de la última capa convoluciónal del modelo preentrenado
#lo vemos en el conv_base.summary()
out_x = 2
out_y = 2
conv_len = 1001

datagen = ImageDataGenerator(rescale = 1./255)

def extract_features(directory, sample_count):
    features = np.zeros(shape=(sample_count, out_x, out_x, conv_len))
    labels = to_categorical(np.zeros(shape=(sample_count)),nb_clases) #INDICAR NUMERO DE CLASES
    generator = datagen.flow_from_directory(
        directory,
        target_size = (height_image, width_image),
        batch_size = batch_size,
        #classes = 4,
        class_mode = 'categorical')
    i = 0
    for inputs_batch, labels_batch in generator:
        features_batch = inception_resnet_v2.predict(inputs_batch) ##Asociamos al modelo preentrenado
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        i += 1
        if i * batch_size >= sample_count:
            break
    return features, labels

#Train: 1000 muestras x clase, con 4 clases, 1000 x 4 = 4000
train_features, train_labels = extract_features(train_dir, nb_train)
#validation 500 muestras x clase con 4 clases, 300 x 4 = 1200
validation_features, validation_labels = extract_features(validation_dir, nb_validation) 
#test 500 muestras x clase con 4 clases, 300 x 4 = 1200
test_features, test_labels = extract_features(test_dir, nb_test)
# Out:
# Found 4000 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %%
#Las características extraídas están como muetras en forma (muestra, 4, 4, 512).-->(muestras, out_x, out_y, conv_len)
#Debemos aplanarlas (muestras, 8192) para alimentar un clasificador densamente conectado 4x4x512 = 8192 si entrada 150x150
#Debemos aplanarlas (muestras, 25088) para alimentar un clasificador densamente conectado 7x7x512 = 25088 si entrada 224x224


train_features = np.reshape(train_features, (nb_train, out_x * out_y * conv_len))
validation_features = np.reshape(validation_features, (nb_validation, out_x * out_y * conv_len))
test_features = np.reshape(test_features, (nb_test, out_x * out_y * conv_len))
print(train_features.shape)
print(validation_features.shape)
print(test_features.shape)
# Out:
# (4000, 4004)
# (1200, 4004)
# (1200, 4004)

# %%
#Definimos un clasificador densamente conectado capacitado con los datos y etiquetas obtenidas antes
#Aplicamos capa de abandono Dropout y función de activación "sigmoid" al final
from keras import layers
from keras import models
from keras import optimizers

top_model = models.Sequential()
top_model.add(layers.Dense(256, activation = 'relu', input_dim = out_x * out_y * conv_len))
top_model.add(layers.Dropout(0.5))
top_model.add(layers.Dense(nb_clases, activation = 'sigmoid'))  #INDICAR NUMERO DE CLASES

top_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 256)               1025280
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 1,026,308
# Trainable params: 1,026,308
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Para la compilación usaremos el optimizador RMSprop ya que termina la red con una sola
#unidad sigmoidea, cómo función de pérdida se utiliza la entropia cruzada binaria

top_model.compile(loss = 'categorical_crossentropy', 
              optimizer = optimizers.RMSprop(lr=2e-5), 
              metrics = ['acc'])

epochs = 80

history = top_model.fit(
    train_features,
    train_labels,  
    batch_size = batch_size,
    epochs = epochs, 
    verbose = 1, 
    validation_data = (validation_features, validation_labels))
# Out:
# Train on 4000 samples, validate on 1200 samples
# Epoch 1/80
# 4000/4000 [==============================] - 7s 2ms/step - loss: 1.3863 - acc: 0.2457 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 2/80
# 4000/4000 [==============================] - 7s 2ms/step - loss: 1.3863 - acc: 0.2585 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 3/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3863 - acc: 0.2525 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 4/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3863 - acc: 0.2552 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 5/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3862 - acc: 0.2603 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 6/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3865 - acc: 0.2410 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 7/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3863 - acc: 0.2485 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 8/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3862 - acc: 0.2532 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 9/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3864 - acc: 0.2460 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 10/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3863 - acc: 0.2565 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 11/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3864 - acc: 0.2502 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 12/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3866 - acc: 0.2507 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 13/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3862 - acc: 0.2507 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 14/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3861 - acc: 0.2575 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 15/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3864 - acc: 0.2510 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 16/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3870 - acc: 0.2373 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 17/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3861 - acc: 0.2608 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 18/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3863 - acc: 0.2462 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 19/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3869 - acc: 0.2445 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 20/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3860 - acc: 0.2538 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 21/80
# 4000/4000 [==============================] - 7s 2ms/step - loss: 1.3864 - acc: 0.2538 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 22/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3867 - acc: 0.2462 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 23/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3866 - acc: 0.2540 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 24/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3865 - acc: 0.2555 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 25/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3871 - acc: 0.2457 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 26/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3868 - acc: 0.2485 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 27/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3865 - acc: 0.2510 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 28/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3870 - acc: 0.2407 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 29/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3866 - acc: 0.2547 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 30/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3861 - acc: 0.2557 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 31/80
# 4000/4000 [==============================] - 7s 2ms/step - loss: 1.3862 - acc: 0.2502 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 32/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3870 - acc: 0.2480 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 33/80
# 4000/4000 [==============================] - 6s 1ms/step - loss: 1.3870 - acc: 0.2480 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 34/80
# 4000/4000 [==============================] - 6s 2ms/step - loss: 1.3873 - acc: 0.2522 - val_loss: 1.3863 - val_acc: 0.2500
# Epoch 35/80
#  678/4000 [====>.........................] - ETA: 4s - loss: 1.3843 - acc: 0.2920
